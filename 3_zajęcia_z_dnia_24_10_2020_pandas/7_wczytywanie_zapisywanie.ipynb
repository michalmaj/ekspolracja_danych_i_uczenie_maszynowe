# %%
import numpy as np
import pandas as pd

# %%
# wczytywanie plików csv

# %%
pd.read_csv('przyklad.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('przyklad.csv')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# zapisywanie

# %%
df.to_csv('moj_plik') # uwaga na dodatkowy indeks

# %%
pd.read_csv('moj_plik') # pojawi się dodatkowa tabela "Unnamed"
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
# żeby temu zapobiec, należy zapisać dane z parametrem index=False:
df.to_csv('moj_plik',index=False)

# %%
pd.read_csv('moj_plik') # teraz będzie bez problemów
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# wczytwanie plików Excel:

# %%
pd.read_excel('przyklad.xlsx',sheet_name='Zeszyt1')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_excel('moj_plik2.xlsx', sheet_name='NowyZeszyt',index=False) # znowu należy pamiętać o index=False!

# %%
pd.read_excel('moj_plik2.xlsx',sheet_name='NowyZeszyt')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# podstawowe scrapownie stroy
dane = pd.read_html('https://pl.wikipedia.org/wiki/Lista_bank%C3%B3w_dzia%C5%82aj%C4%85cych_w_Polsce')

# %%
type(dane)
# Out:
# list

# %%
# wyciągnięcie DataFrame z listy
dane[0]
# Out:
#     L.p.                                     Nazwa Aktywa (mld PLN)  \
# 0    1.0  Powszechna Kasa Oszczędności Bank Polski              286
# 1    2.0                   Bank Polska Kasa Opieki              174
# 2    3.0                     Santander Bank Polska              150
# 3    4.0                                     mBank              134
# 4    5.0                           ING Bank Śląski              117
# 5    6.0                   BNP Paribas Bank Polska               72
# 6    7.0                           Bank Millennium               69
# 7    8.0                          Getin Noble Bank               67
# 8    9.0                                Alior Bank               61
# 9   10.0                    Raiffeisen Bank Polska               53
# 10  11.0                 Bank Handlowy w Warszawie               45
# 11  12.0                      Deutsche Bank Polska            40[9]
# 12  13.0                                 Idea Bank               22
# ...

# %%
dane[0].head() # wyświetli 5 pierwszych
# Out:
#    L.p.                                     Nazwa Aktywa (mld PLN)  \
# 0   1.0  Powszechna Kasa Oszczędności Bank Polski              286
# 1   2.0                   Bank Polska Kasa Opieki              174
# 2   3.0                     Santander Bank Polska              150
# 3   4.0                                     mBank              134
# 4   5.0                           ING Bank Śląski              117
#
#                               Inwestor dominujący  \
# 0  Skarb Państwa RP poprzez Ministerstwo Finansów
# 1                               PZU S.A. (Polska)
# 2                     Banco Santander (Hiszpania)
# 3                         Commerzbank AG (Niemcy)
# 4                          ING Bank NV (Holandia)
#
#   Ilość akcji głównego udziałowca (%)  \
# 0                                2943
# 1                                  20
# 2                                6934
# 3                                6937
# 4                                  75
#
# ...

# %%
# bazy danych

# %%
# tworzenie prostej bazy w pamięci
from sqlalchemy import create_engine

# %%
# tworzy tymczasową niewielką bazę danych w pamięci
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('moja_tabela',engine)

# %%
sqldf = pd.read_sql('moja_tabela',con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
